# %% [markdown]
# После добавления лемматизации и обучения модели на новой выборке, результат улучшился:
#
# Макросредняя F1 мера -  0.463064212113 –> 0.571347643355
# Микросредняя F1 мера -  0.638753651412 –> 0.699123661149
#
# Стоп-слова были взяты отсюда – https://github.com/stopwords-iso/stopwords-ru/blob/master/raw/stop-words-russian.txt
#
# _______________________________
#
# Значимые слова (признаки) для класса -  -1
# ['гавно', 'tele2', 'крым', 'изза', 'ловить', 'работать', 'сука', 'билайн', 'связь', 'отключать']
#
# Можно заметить, что большинство слов несет негативный характер. Весьма четкий список слов для данного класса.
#
# Значимые слова (признаки) для класса -  0
# ['гавно', 'работать', 'инструкция', 'ловить', 'настройка', 'скачать', 'доллар', 'телефон', 'восстановление', 'модем']
#
# Сранный набор признаков, если учесть, что есть пересечения с классом "-1". "гавно" одназначно можно считать мусорным.
#
# Значимые слова (признаки) для класса -  1
# ['узбекистан', 'любить', 'бесплатный', 'хороший', 'запускать', 'зарабатывать', 'защита', 'большой', 'подарок', 'реклама']
#
# Нормальный надоб слов для положительной тональности, только напрягает "Узбекистан" и "реклама".
#
# _______________________________
